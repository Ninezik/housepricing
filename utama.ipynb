# %%
print('saya zikri')
# Out:
# saya zikri

# %%
print('saya coba push pertama kali')
# Out:
# saya coba push pertama kali

# %%
print('hai ini zikri nurzani')
# Out:
# hai ini zikri nurzani

# %%
print('heal the world by michael jackson')
# Out:
# heal the world by michael jackson

# %%
print('we are the world by michael jackson')
# Out:
# we are the world by michael jackson
